# %%
import pandas as pd
import numpy as np
import os
import openai
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoTokenizer, AutoModel
import torch

# %%
openai.api_key = "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"

# %%
data_path = "nbme-score-clinical-patient-notes/"
os.listdir(data_path)
# Out:
# ['features.csv',
#  'patient_notes.csv',
#  'sample_submission.csv',
#  'test.csv',
#  'train.csv']

# %%
 features = pd.read_csv(data_path + 'features.csv')
 patient_notes = pd.read_csv(data_path + 'patient_notes.csv')
 sample_submission = pd.read_csv(data_path + 'sample_submission.csv')
 training_data = pd.read_csv(data_path + 'train.csv')
 test_data = pd.read_csv(data_path + 'train.csv')

# %%
patient_notes
# Out:
#        pn_num  case_num                                         pn_history
# 0           0         0  17-year-old male, has come to the student heal...
# 1           1         0  17 yo male with recurrent palpitations for the...
# 2           2         0  Dillon Cleveland is a 17 y.o. male patient wit...
# 3           3         0  a 17 yo m c/o palpitation started 3 mos ago; \...
# 4           4         0  17yo male with no pmh here for evaluation of p...
# ...       ...       ...                                                ...
# 42141   95330         9  Ms. Madden is a 20 yo female presenting w/ the...
# 42142   95331         9  A 20 YO F CAME COMPLAIN A DULL 8/10 HEADACHE T...
# 42143   95332         9  Ms. Madden is a 20yo female who presents with ...
# 42144   95333         9  Stephanie madden is a 20 year old woman compla...
# 42145   95334         9  patient is a 20 yo F who presents with a heada...
#
# [42146 rows x 3 columns]

# %%
features
# Out:
#      feature_num  case_num                                       feature_text
# 0              0         0  Family-history-of-MI-OR-Family-history-of-myoc...
# 1              1         0                 Family-history-of-thyroid-disorder
# 2              2         0                                     Chest-pressure
# 3              3         0                              Intermittent-symptoms
# 4              4         0                                        Lightheaded
# ..           ...       ...                                                ...
# 138          912         9                        Family-history-of-migraines
# 139          913         9                                             Female
# 140          914         9                                        Photophobia
# 141          915         9                          No-known-illness-contacts
# 142          916         9                                   Subjective-fever
#
# [143 rows x 3 columns]

# %%
# Load list of expected concepts

# Initialize features list for cases
expected_concepts = []

for i in range(10):
    expected_concepts.append([])
    feat = features.loc[features['case_num'] == i, 'feature_text']
    for f in feat:
        f = f.lower().replace('-', ' ')
        expected_concepts[i].append(f)

# %%
training_data
# Out:
#               id  case_num  pn_num  feature_num  \
# 0      00016_000         0      16            0
# 1      00016_001         0      16            1
# 2      00016_002         0      16            2
# 3      00016_003         0      16            3
# 4      00016_004         0      16            4
# ...          ...       ...     ...          ...
# 14295  95333_912         9   95333          912
# 14296  95333_913         9   95333          913
# 14297  95333_914         9   95333          914
# 14298  95333_915         9   95333          915
# 14299  95333_916         9   95333          916
#
#                                      annotation              location
# 0              ['dad with recent heart attcak']           ['696 724']
# 1                 ['mom with "thyroid disease']           ['668 693']
# 2                            ['chest pressure']           ['203 217']
# 3          ['intermittent episodes', 'episode']  ['70 91', '176 183']
# 4      ['felt as if he were going to pass out']           ['222 258']
# ...                                         ...                   ...
# 14295                                        []                    []
# 14296                                        []                    []
# 14297                              ['photobia']           ['274 282']
# 14298                      ['no sick contacts']           ['421 437']
# 14299                      ['Subjective fever']           ['314 330']
#
# [14300 rows x 6 columns]

# %%
# Get list of training ids
training_ids = training_data['pn_num'].unique()

# Get training scores
# Initialize list of training scores
training_scores = []
training_counts = []
expected_counts = []


temp = []

for i in training_ids:
    # Pull corresponding patient notes
    temp.append(patient_notes[patient_notes['pn_num'] == i])
    
    # Get case number
    c_num = training_data.loc[training_data['pn_num'] == i, 'case_num'].iloc[0]
    e_count = len(expected_concepts[c_num])
    
    # Calculate score
    t_count = len(training_data.loc[(training_data['pn_num'] == i) & (training_data['annotation'] != '[]')])
    t_score = t_count / len(expected_concepts[c_num])
    expected_counts.append(e_count)
    training_scores.append(t_score)
    training_counts.append(t_count)

# %%
# Create truncated list of notes based on training set

patient_notes_short = pd.concat(temp)

# Add training scores
patient_notes_short['Max Features'] = expected_counts
patient_notes_short['Expected Count'] = training_counts
patient_notes_short['Expected Score'] = training_scores

patient_notes_short
# Out:
#        pn_num  case_num                                         pn_history  \
# 16         16         0  HPI: 17yo M presents with palpitations. Patien...
# 40         41         0  17 Y/O M CAME TO THE CLINIC C/O HEART POUNDING...
# 45         46         0  Mr. Cleveland is a 17yo M who was consented by...
# 79         82         0  17 yo M w/ no cardiac or arrhythmia PMH presen...
# 96        100         0  HPI: Dillon Cleveland is an otherwise healthy ...
# ...       ...       ...                                                ...
# 41963   95145         9  Pt is 20 yo F w headache since yesterday morni...
# 42042   95228         9  20 F no PMH, lives w/ roommate in apartment ha...
# 42056   95243         9  20 y/o F with no PMH is presenting with 1 day ...
# 42141   95330         9  Ms. Madden is a 20 yo female presenting w/ the...
# 42144   95333         9  Stephanie madden is a 20 year old woman compla...
#
#        Max Features  Expected Count  Expected Score
# 16               13              10        0.769231
# 40               13               8        0.615385
# 45               13              11        0.846154
# 79               13              10        0.769231
# 96               13              10        0.769231
# ...             ...             ...             ...
# 41963            17              11        0.647059
# 42042            17               7        0.411765
# 42056            17               9        0.529412
# 42141            17              12        0.705882
# 42144            17              10        0.588235
#
# [1000 rows x 6 columns]

# %% [markdown]
# ***Use GPT-3 to find matching features in patient notes from the list of expected concepts.***

# %%
# Initialize list for feature scores and count of matching features
f_scores = []
f_counts = []

# Use GPT-3 to count the number of features found in the student's notes
for n in range(len(patient_notes_short)):
    note = patient_notes_short['pn_history'].iloc[n].replace('\r\n', '')
    c_num = patient_notes_short['case_num'].iloc[n]

    # Create a prompt to match the phrases in the text and count them
    prompt = f"Count the number of concepts in the list, {expected_concepts[c_num]}, that can be found in the following text:\n\nText: {note}\n\n And list the matching phrases from the text.\n\nCount:"

    response = openai.Completion.create(
        engine="text-davinci-002", 
        prompt=prompt,
        max_tokens=1,
        n=2,
        stop=None,
        temperature=0.5
    )

    f_count = int(response.choices[0].text.strip())
    f_score = f_count/len(expected_concepts[c_num])
    f_scores.append(f_score)
    f_counts.append(f_count)

# %%
# Append feature counts and scores to notes table
patient_notes_short['Feature Count'] = f_counts
patient_notes_short['Feature Score'] = f_scores

patient_notes_short['Feature Error'] = abs(patient_notes_short['Expected Score'] - patient_notes_short['Feature Score']) / patient_notes_short['Expected Score']
patient_notes_short
# Out:
#        pn_num  case_num                                         pn_history  \
# 16         16         0  HPI: 17yo M presents with palpitations. Patien...
# 40         41         0  17 Y/O M CAME TO THE CLINIC C/O HEART POUNDING...
# 45         46         0  Mr. Cleveland is a 17yo M who was consented by...
# 79         82         0  17 yo M w/ no cardiac or arrhythmia PMH presen...
# 96        100         0  HPI: Dillon Cleveland is an otherwise healthy ...
# ...       ...       ...                                                ...
# 41963   95145         9  Pt is 20 yo F w headache since yesterday morni...
# 42042   95228         9  20 F no PMH, lives w/ roommate in apartment ha...
# 42056   95243         9  20 y/o F with no PMH is presenting with 1 day ...
# 42141   95330         9  Ms. Madden is a 20 yo female presenting w/ the...
# 42144   95333         9  Stephanie madden is a 20 year old woman compla...
#
#        Max Features  Expected Count  Expected Score  Feature Count  \
# 16               13              10        0.769231              7
# 40               13               8        0.615385              8
# 45               13              11        0.846154              8
# 79               13              10        0.769231              9
# 96               13              10        0.769231              5
# ...             ...             ...             ...            ...
# 41963            17              11        0.647059             20
# 42042            17               7        0.411765             14
# 42056            17               9        0.529412             14
# 42141            17              12        0.705882             20
# 42144            17              10        0.588235             20
#
#        Feature Score  Feature Error
# 16          0.538462       0.300000
# 40          0.615385       0.000000
# 45          0.615385       0.272727
# 79          0.692308       0.100000
# 96          0.384615       0.500000
# ...              ...            ...
# 41963       1.176471       0.818182
# 42042       0.823529       1.000000
# 42056       0.823529       0.555556
# 42141       1.176471       0.666667
# 42144       1.176471       1.000000
#
# [1000 rows x 9 columns]

# %% [markdown]
# ***Use GPT-3 to generate "ideal" patient notes with all expected concepts.***

# %%
# Initialize list for generated notes
generated_note = []

for c in expected_concepts:
    print(c)
    prompt = (f'Given concepts in this list {c}, generate a patient note')
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        temperature=0,
        max_tokens=1500,
        n=2,
        stop=None,
        frequency_penalty=0,
        presence_penalty=0
        )
    note = response.choices[0].text.replace('.\n', '').replace('\n', '')
    print('\n' + note + '\n')
    generated_note.append(note)
# Out:
# ['family history of mi or family history of myocardial infarction', 'family history of thyroid disorder', 'chest pressure', 'intermittent symptoms', 'lightheaded', 'no hair changes or no nail changes or no temperature intolerance', 'adderall use', 'shortness of breath', 'caffeine use', 'heart pounding or heart racing', 'few months duration', '17 year', 'male']
#
# Patient is a 17 year old male with a family history of myocardial infarction who presents with intermittent chest pressure, lightheadedness, and shortness of breath for the last few months. He also reports that he has been using Adderall and caffeine regularly and has noticed that his heart has been pounding or racing more frequently. There are no changes in his hair or nails, and he has not experienced any temperature intolerance.
#
# ['no vaginal discharge', 'weight loss', 'not sexually active', 'prior episodes of diarrhea', '20 year', 'no bloody bowel movements', 'recurrent bouts over past 6 months', 'right sided lq abdominal pain or right lower quadrant abdominal pain', 'no urinary symptoms', 'diminished appetite', 'normal lmp 2 weeks ago or normal last menstrual period 2 weeks ago', '8 to 10 hours of acute pain', 'female']
#
# Patient is a 20 year old female who is not sexually active and has had no prior episodes of diarrhea. She has been experiencing recurrent bouts of right sided lower quadrant abdominal pain over the past 6 months, with diminished appetite and weight loss. She has normal LMP 2 weeks ago and 8-10 hours of acute pain.
#
# ['prior normal periods', 'last pap smear i year ago', 'iud', 'sexually active', 'vaginal dryness', 'irregular menses', 'recent nausea vomiting or recent flulike symptoms', 'no premenstrual symptoms', 'female', 'stress', 'lmp 2 months ago or last menstrual period 2 months ago', 'hot flashes', 'irregular flow or irregular frequency or irregular intervals', 'onset 3 years ago', 'heavy sweating', 'sleep disturbance or early awakenings', '44 year']
#
# The patient is a 44-year-old female who is sexually active and has an IUD. She has had irregular menses for the past 3 years, with a heavy flow and irregular frequency. She has also experienced hot flashes, vaginal dryness, and sleep disturbance. She has no premenstrual symptoms. She reports a prior normal pap smear one year ago and has had no recent nausea, vomiting, or flu-like symptoms.
#
# ['fhx of pud or family history of peptic ulcer disease', 'epigastric discomfort', 'darker bowel movements', 'nsaid use or nonsteroidal anti inflammatory drug use', 'burning or gnawing or burning and gnawing', 'post prandial bloating or fullness with meals', 'getting worse or progressive or symptoms now daily', '2 to 3 beers a week', 'male', 'duration 2 months', 'awakens at night', 'no blood in stool', 'intermittent', 'minimal to no change with tums', 'nausea', '35 year']
#
# The patient is a 35-year-old male with a two-month history of epigastric discomfort, dark bowel movements, and burning or gnawing. He has a family history of peptic ulcer disease and uses NSAIDs. His symptoms are worse after meals, and he has progressive bloating and fullness. He has no blood in his stool, but his symptoms are now daily. He has tried Tums with minimal to no relief. He also has nausea.
#
# ['lack of other thyroid symptoms', 'anxious or nervous', 'stress due to caring for elderly parents', 'heavy caffeine use', 'no depressed mood', 'weight stable', 'insomnia', 'female', 'decreased appetite', '45 year']
#
# Patient presents with lack of other thyroid symptoms, anxious or nervous, stress due to caring for elderly parents, heavy caffeine use, no depressed mood, weight stable, insomnia, decreased appetite. The patient is a 45 year old female.
#
# ['onset 5 years ago', 'female', 'no caffeine use', 'associated sob or associated shortness of breath', 'episodes of heart racing', 'recent visit to emergency department with negative workup', 'no chest pain', 'no illicit drug use', 'associated nausea', 'increased frequency recently', 'associated feeling of impending doom', 'episodes last 15 to 30 minutes', 'associated throat tightness', 'feels hot or feels clammy', 'episode of hand numbness or episode of finger numbness', 'fatigue or difficulty concentrating', 'increased stress', '26 year']
#
# Patient is a 26-year-old female who presented with a chief complaint of episodes of heart racing that have increased in frequency recently, associated with feeling of impending doom, shortness of breath, and nausea. She has had these episodes for the past 5 years, and they typically last 15-30 minutes. She denies any chest pain, but reports feeling hot or clammy and having episodes of hand or finger numbness. She also reports fatigue and difficulty concentrating. She denies any illicit drug use or recent visits to the emergency department. She reports that her symptoms are worse with increased stress.
#
# ['subjective fevers', 'male', '17 year', 'recent upper respiratory symptoms', 'worse with deep breath or pleuritic', 'exercise induced asthma', 'chest pain', 'duration x 1 day', 'no shortness of breath', 'recent heavy lifting at work or recent rock climbing', 'no relief with asthma inhaler', 'sharp or stabbing or 7 to 8 out of 10 on pain scale']
#
# The patient is a 17-year-old male with recent upper respiratory symptoms who presents with subjective fevers and worse with deep breath or pleuritic chest pain. He endorses exercise-induced asthma and reports no shortness of breath. The patient has been doing some heavy lifting at work or recent rock climbing and has not had any relief with his asthma inhaler. He rates his pain as sharp or stabbing and 7 to 8 out of 10 on the pain scale.
#
# ['female', 'weight gain', 'heavy periods or irregular periods', 'last menstrual period 2 months ago', 'unprotected sex', 'fatigue', 'infertility hx or infertility history', '35 year', 'symptoms for 6 months']
#
# Patient is a 35-year-old female with a history of infertility who has been experiencing symptoms for the past 6 months, including fatigue, heavy or irregular periods, and weight gain. She had unprotected sex 2 months ago and has not had a period since then. She is concerned about her symptoms and wants to know what could be causing them.
#
# ['increased appetite', 'son died 3 weeks ago', 'female', 'auditory hallucination once', 'tossing and turning', '67 year', 'difficulty falling asleep', 'hallucinations after taking ambien', 'duration 3 weeks', 'unsuccessful napping', 'sleeping medication ineffective', 'diminished energy or feeling drained', 'loss of interest', 'visual hallucination once', 'fhx of depression or family history of depression', 'early wakening', 'no suicidal ideations', 'difficulty with sleep']
#
# Patient is a 67-year-old female who reports difficulty falling asleep, tossing and turning, and early wakening for the past 3 weeks. She has also noted diminished energy and feeling drained. She has tried taking a sleeping medication but found it to be ineffective. The patient denies any suicidal ideations. She has a family history of depression.
#
# ['no relief with motrin or no relief with tylenol', '20 year', '1 day duration or 2 days duration', 'myalgias', 'global headache or diffuse headache', 'neck pain', 'vomiting', 'no rash', 'nausea', 'viral symptoms or rhinorrhea or scratchy throat', 'shares an apartment', 'meningococcal vaccine status unknown', 'family history of migraines', 'female', 'photophobia', 'no known illness contacts', 'subjective fever']
#
# Patient is a 20 year old female with diffuse headache, myalgias, neck pain, nausea, vomiting, and subjective fever for 1-2 days. She has no relief with Motrin or Tylenol, photophobia, and no known illness contacts. She shares an apartment and her meningococcal vaccine status is unknown. She has a family history of migraines.

# %%
# Generate cosine similarity scores between the generated notes and the student notes

# Load pre-trained BERT model and tokenizer
model_name = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Initialize list for similarity scores
sim_scores = []

# Loop through notes and generate scores
for n in range(len(patient_notes_short)):
    note = patient_notes_short['pn_history'].iloc[n].replace('\r\n', '')
    c_num = patient_notes_short['case_num'].iloc[n]
    
    # Tokenize the texts
    tokens1 = tokenizer(generated_note[c_num], return_tensors='pt')
    tokens2 = tokenizer(note, return_tensors='pt')

    # Pass the tokenized inputs through the model to get the embeddings
    with torch.no_grad():
        outputs1 = model(**tokens1)
        outputs2 = model(**tokens2)
    embeddings1 = outputs1[0][:, 0, :]
    embeddings2 = outputs2[0][:, 0, :]

    # Compute cosine similarity between the embeddings
    cos_sim = torch.nn.functional.cosine_similarity(embeddings1, embeddings2)
    
    sim_scores.append(cos_sim.item())
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Append feature scores to notes table
patient_notes_short['Similarity Score'] = sim_scores

patient_notes_short['Similarity Error'] = abs(patient_notes_short['Expected Score'] - patient_notes_short['Similarity Score']) / patient_notes_short['Expected Score']
patient_notes_short
# Out:
#        pn_num  case_num                                         pn_history  \
# 16         16         0  HPI: 17yo M presents with palpitations. Patien...
# 40         41         0  17 Y/O M CAME TO THE CLINIC C/O HEART POUNDING...
# 45         46         0  Mr. Cleveland is a 17yo M who was consented by...
# 79         82         0  17 yo M w/ no cardiac or arrhythmia PMH presen...
# 96        100         0  HPI: Dillon Cleveland is an otherwise healthy ...
# ...       ...       ...                                                ...
# 41963   95145         9  Pt is 20 yo F w headache since yesterday morni...
# 42042   95228         9  20 F no PMH, lives w/ roommate in apartment ha...
# 42056   95243         9  20 y/o F with no PMH is presenting with 1 day ...
# 42141   95330         9  Ms. Madden is a 20 yo female presenting w/ the...
# 42144   95333         9  Stephanie madden is a 20 year old woman compla...
#
#        Max Features  Expected Count  Expected Score  Feature Count  \
# 16               13              10        0.769231              7
# 40               13               8        0.615385              8
# 45               13              11        0.846154              8
# 79               13              10        0.769231              9
# 96               13              10        0.769231              5
# ...             ...             ...             ...            ...
# 41963            17              11        0.647059             20
# 42042            17               7        0.411765             14
# 42056            17               9        0.529412             14
# 42141            17              12        0.705882             20
# 42144            17              10        0.588235             20
#
#        Feature Score  Feature Error  Similarity Score  Similarity Error
# 16          0.538462       0.300000          0.735527          0.043815
# 40          0.615385       0.000000          0.649276          0.055074
# 45          0.615385       0.272727          0.808809          0.044135
# 79          0.692308       0.100000          0.751793          0.022670
# 96          0.384615       0.500000          0.784450          0.019786
# ...              ...            ...               ...               ...
# 41963       1.176471       0.818182          0.773857          0.195961
# 42042       0.823529       1.000000          0.824466          1.002274
# 42056       0.823529       0.555556          0.861683          0.627623
# 42141       1.176471       0.666667          0.864480          0.224680
# 42144       1.176471       1.000000          0.835173          0.419794
#
# [1000 rows x 11 columns]

# %%
# Average Errors
print(f'The average Feature Error was: {patient_notes_short["Feature Error"].mean()}')
      
print(f'The average Similarity Error was: {patient_notes_short["Similarity Error"].mean()}')
# Out:
# The average Feature Error was: 0.36211485736485804
# The average Similarity Error was: 0.2281997214408971

# %%
# Save results to file
patient_notes_short.to_csv("patient_notes_scores.csv", index=False)

# %%
# Generate notes with temperature=0.7
generated_note2 = []

for c in expected_concepts:
    print(c)
    prompt = (f'Given concepts in this list {c}, generate a patient note')
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=prompt,
        temperature=0.7,
        max_tokens=1500,
        n=2,
        stop=None,
        frequency_penalty=0,
        presence_penalty=0
        )
    note = response.choices[0].text.replace('.\n', '').replace('\n', '')
    print('\n' + note + '\n')
    generated_note2.append(note)
# Out:
# ['family history of mi or family history of myocardial infarction', 'family history of thyroid disorder', 'chest pressure', 'intermittent symptoms', 'lightheaded', 'no hair changes or no nail changes or no temperature intolerance', 'adderall use', 'shortness of breath', 'caffeine use', 'heart pounding or heart racing', 'few months duration', '17 year', 'male']
#
# Patient presents with a chief complaint of intermittent chest pressure and shortness of breath for the last few months. He endorses lightheadedness and heart pounding/racing with these episodes. He has a family history of myocardial infarction and thyroid disorder. He takes Adderall and drinks caffeine regularly. He denies any changes in his hair or nails and has no temperature intolerance. He is a 17-year-old male.
#
# ['no vaginal discharge', 'weight loss', 'not sexually active', 'prior episodes of diarrhea', '20 year', 'no bloody bowel movements', 'recurrent bouts over past 6 months', 'right sided lq abdominal pain or right lower quadrant abdominal pain', 'no urinary symptoms', 'diminished appetite', 'normal lmp 2 weeks ago or normal last menstrual period 2 weeks ago', '8 to 10 hours of acute pain', 'female']
#
# The patient is a 20-year-old female who presents with recurrent bouts of diarrhea over the past 6 months. She reports 8 to 10 hours of acute pain, diminished appetite, and weight loss. She is not sexually active and has had no vaginal discharge. She has had prior episodes of diarrhea and reports normal last menstrual period 2 weeks ago. She has no bloody bowel movements and no urinary symptoms. She endorses right-sided lower quadrant abdominal pain.
#
# ['prior normal periods', 'last pap smear i year ago', 'iud', 'sexually active', 'vaginal dryness', 'irregular menses', 'recent nausea vomiting or recent flulike symptoms', 'no premenstrual symptoms', 'female', 'stress', 'lmp 2 months ago or last menstrual period 2 months ago', 'hot flashes', 'irregular flow or irregular frequency or irregular intervals', 'onset 3 years ago', 'heavy sweating', 'sleep disturbance or early awakenings', '44 year']
#
# Patient is a 44-year-old female with a last menstrual period 2 months ago and a history of irregular menses. She reports vaginal dryness, hot flashes, and heavy sweating. She is sexually active and has an IUD. She has no premenstrual symptoms. She has had irregular flow or irregular frequency or irregular intervals for the past 3 years. She has had a pap smear within the last year.
#
# ['fhx of pud or family history of peptic ulcer disease', 'epigastric discomfort', 'darker bowel movements', 'nsaid use or nonsteroidal anti inflammatory drug use', 'burning or gnawing or burning and gnawing', 'post prandial bloating or fullness with meals', 'getting worse or progressive or symptoms now daily', '2 to 3 beers a week', 'male', 'duration 2 months', 'awakens at night', 'no blood in stool', 'intermittent', 'minimal to no change with tums', 'nausea', '35 year']
#
# The patient is a 35-year-old male with a two-month history of epigastric discomfort, dark bowel movements, and post-prandial bloating or fullness with meals. The patient has also been awakened at night by his symptoms. He reports that there is no blood in his stool and that his symptoms are intermittent. He has tried taking Tums with minimal to no change. The patient also reports nausea. The patient has a family history of peptic ulcer disease and drinks 2-3 beers per week.
#
# ['lack of other thyroid symptoms', 'anxious or nervous', 'stress due to caring for elderly parents', 'heavy caffeine use', 'no depressed mood', 'weight stable', 'insomnia', 'female', 'decreased appetite', '45 year']
#
# Patient presents with symptoms of anxiety and insomnia. She reports that her weight is stable and she has no depressed mood. She states that she has been under a lot of stress due to caring for her elderly parents. She reports that she uses a lot of caffeine and has decreased appetite. She is a 45-year-old female.
#
# ['onset 5 years ago', 'female', 'no caffeine use', 'associated sob or associated shortness of breath', 'episodes of heart racing', 'recent visit to emergency department with negative workup', 'no chest pain', 'no illicit drug use', 'associated nausea', 'increased frequency recently', 'associated feeling of impending doom', 'episodes last 15 to 30 minutes', 'associated throat tightness', 'feels hot or feels clammy', 'episode of hand numbness or episode of finger numbness', 'fatigue or difficulty concentrating', 'increased stress', '26 year']
#
# Patient is a 26 year old female who presented with new onset of symptoms 5 years ago. She has episodes of heart racing, associated with sob or shortness of breath, that have increased in frequency recently. She also has associated nausea, feeling of impending doom, and throat tightness. These episodes last 15-30 minutes and she feels hot or clammy during them. She has also had an episode of hand numbness. She denies any chest pain, illicit drug use, or recent visit to the ED. She does report that she is more stressed recently. She has no known caffeine use.
#
# ['subjective fevers', 'male', '17 year', 'recent upper respiratory symptoms', 'worse with deep breath or pleuritic', 'exercise induced asthma', 'chest pain', 'duration x 1 day', 'no shortness of breath', 'recent heavy lifting at work or recent rock climbing', 'no relief with asthma inhaler', 'sharp or stabbing or 7 to 8 out of 10 on pain scale']
#
# The patient is a 17-year-old male with a history of subjective fevers and recent upper respiratory symptoms. He reports that his symptoms are worse with deep breath or pleuritic chest pain and that he has had exercise-induced asthma in the past. The patient has no shortness of breath or recent heavy lifting at work or recent rock climbing. He reports that his asthma inhaler provides no relief. He rates his pain as sharp or stabbing and 7 to 8 out of 10 on the pain scale.
#
# ['female', 'weight gain', 'heavy periods or irregular periods', 'last menstrual period 2 months ago', 'unprotected sex', 'fatigue', 'infertility hx or infertility history', '35 year', 'symptoms for 6 months']
#
# Patient is a 35-year-old female who comes in with complaints of fatigue, heavy or irregular periods, and weight gain for the last six months. She reports that her last menstrual period was two months ago. She has a history of infertility and unprotected sex.
#
# ['increased appetite', 'son died 3 weeks ago', 'female', 'auditory hallucination once', 'tossing and turning', '67 year', 'difficulty falling asleep', 'hallucinations after taking ambien', 'duration 3 weeks', 'unsuccessful napping', 'sleeping medication ineffective', 'diminished energy or feeling drained', 'loss of interest', 'visual hallucination once', 'fhx of depression or family history of depression', 'early wakening', 'no suicidal ideations', 'difficulty with sleep']
#
#  that includes three sentences that would be appropriate for a psychiatric evaluationThe patient is a 67 year old female with a 3 week history of difficulty falling asleep, early wakening, and tossing and turning. She reports that her sleeping medication has been ineffective and she has had difficulty napping. She has also had diminished energy or feeling drained and loss of interest. The patient has had one auditory hallucination and one visual hallucination. She has no current suicidal ideations. The patient's son died 3 weeks ago. The patient has a family history of depression.
#
# ['no relief with motrin or no relief with tylenol', '20 year', '1 day duration or 2 days duration', 'myalgias', 'global headache or diffuse headache', 'neck pain', 'vomiting', 'no rash', 'nausea', 'viral symptoms or rhinorrhea or scratchy throat', 'shares an apartment', 'meningococcal vaccine status unknown', 'family history of migraines', 'female', 'photophobia', 'no known illness contacts', 'subjective fever']
#
# Patient is a 20 year old female with diffuse headache, myalgias, neck pain, vomiting, nausea, and subjective fever for 1-2 days. She has no relief with Motrin or Tylenol. She has no known illness contacts and her meningococcal vaccine status is unknown. She shares an apartment and has a family history of migraines. She is photophobic.

# %%
# Generate cosine similarity scores between the generated notes and the student notes

# Load pre-trained BERT model and tokenizer
model_name = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# Initialize list for similarity scores
sim_scores = []

# Loop through notes and generate scores
for n in range(len(patient_notes_short)):
    note = patient_notes_short['pn_history'].iloc[n].replace('\r\n', '')
    c_num = patient_notes_short['case_num'].iloc[n]
    
    # Tokenize the texts
    tokens1 = tokenizer(generated_note2[c_num], return_tensors='pt')
    tokens2 = tokenizer(note, return_tensors='pt')

    # Pass the tokenized inputs through the model to get the embeddings
    with torch.no_grad():
        outputs1 = model(**tokens1)
        outputs2 = model(**tokens2)
    embeddings1 = outputs1[0][:, 0, :]
    embeddings2 = outputs2[0][:, 0, :]

    # Compute cosine similarity between the embeddings
    cos_sim = torch.nn.functional.cosine_similarity(embeddings1, embeddings2)
    
    sim_scores.append(cos_sim.item())
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# Append feature scores to notes table
patient_notes_short['Similarity Score'] = sim_scores

patient_notes_short['Similarity Error'] = abs(patient_notes_short['Expected Score'] - patient_notes_short['Similarity Score']) / patient_notes_short['Expected Score']
patient_notes_short
# Out:
#        pn_num  case_num                                         pn_history  \
# 16         16         0  HPI: 17yo M presents with palpitations. Patien...
# 40         41         0  17 Y/O M CAME TO THE CLINIC C/O HEART POUNDING...
# 45         46         0  Mr. Cleveland is a 17yo M who was consented by...
# 79         82         0  17 yo M w/ no cardiac or arrhythmia PMH presen...
# 96        100         0  HPI: Dillon Cleveland is an otherwise healthy ...
# ...       ...       ...                                                ...
# 41963   95145         9  Pt is 20 yo F w headache since yesterday morni...
# 42042   95228         9  20 F no PMH, lives w/ roommate in apartment ha...
# 42056   95243         9  20 y/o F with no PMH is presenting with 1 day ...
# 42141   95330         9  Ms. Madden is a 20 yo female presenting w/ the...
# 42144   95333         9  Stephanie madden is a 20 year old woman compla...
#
#        Max Features  Expected Count  Expected Score  Similarity Score  \
# 16               13              10        0.769231          0.792075
# 40               13               8        0.615385          0.752111
# 45               13              11        0.846154          0.831027
# 79               13              10        0.769231          0.830136
# 96               13              10        0.769231          0.818508
# ...             ...             ...             ...               ...
# 41963            17              11        0.647059          0.777010
# 42042            17               7        0.411765          0.834667
# 42056            17               9        0.529412          0.867474
# 42141            17              12        0.705882          0.855366
# 42144            17              10        0.588235          0.827935
#
#        Similarity Error
# 16             0.029697
# 40             0.222180
# 45             0.017878
# 79             0.079177
# 96             0.064061
# ...                 ...
# 41963          0.200834
# 42042          1.027049
# 42056          0.638562
# 42141          0.211768
# 42144          0.407490
#
# [1000 rows x 8 columns]

# %%
# Average Errors with temperature=0.7
print(f'The average Similarity Error was: {patient_notes_short["Similarity Error"].mean()}')
# Out:
# The average Similarity Error was: 0.24812209410284494
